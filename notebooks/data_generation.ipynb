# %% [markdown]
# # Data Generation & Augmentation
#
# This notebook was intended for exploring synthetic data generation and augmentation strategies.
# The final model was trained on real ultrasound data.
